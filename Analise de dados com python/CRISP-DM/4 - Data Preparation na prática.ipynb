# %% [markdown]
# ## **Módulo Matéria 04** - Análise de Regressão em Python Parte 03 Crisp-DM

# %% [markdown]
# ## Data Preparation na prática

# %% [markdown]
# ### 314 Data Preparation na prática pt 01
# ###### df = Dataframe
# ###### NLP = Natural Language Processing
# ###### Apply - função que pode ser aplicada a uma coluna ou linha
# ###### Lambda - indicativo que vou criar minha própria função
# ###### Strip - função do panda string remover alguma coisa no começo ou final
# ###### Regex - Regular Expressions forma bem útil e eficiente para coletar informações em strings, encontrar padrões de textos
# ###### Datetime panda types
# <p>TEMA CENTRAL: Preparação de dados (data preparation) seguindo o processo CRISP-DM</p><p>TÓPICOS ABORDADOS:</p><ul><li>Importação de dados</li><li>Análise inicial do dataframe</li><li>Seleção de dados (select data)<ul><li>Remoção de colunas desnecessárias</li></ul></li><li>Limpeza de dados (data cleaning)<ul><li>Correção de tipos de dados incorretos</li><li>Remoção de caracteres indesejados com expressões regulares (regex)</li></ul></li><li>Formatação de dados<ul><li>Conversão de strings em datas</li></ul></li><li>Construção de novos dados (construct data)<ul><li>Criação de coluna com tempo de duração da campanha</li></ul></li><li>Integração de dados (integrate data)<ul><li>Importação de outro dataframe com dados de campanha</li></ul></li></ul><p>Em cada tópico o vídeo mostra na prática a aplicação dessas tarefas de preparação de dados em um dataframe com dados de campanhas do Kickstarter, utilizando Python e Pandas.</p>

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-55a169de-976d-4fb8-974c-aa3389e0488d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-55a169de-976d-4fb8-974c-aa3389e0488d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("DataPrepFinal.csv")

# %%
df.head()
# Out:
#    Unnamed: 0          ID                                               name  \
# 0           0  1000002330                    The Songs of Adelaide & Abullah
# 1           1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2           2  1000004038                                     Where is Hank?
# 3           3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4           4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency  deadline     goal        launched  \
# 0          Poetry    Publishing      GBP  09/10/15   100000  11/08/15 12:12
# 1  Narrative Film  Film & Video      USD  01/11/17  3000000  02/09/17 04:43
# 2  Narrative Film  Film & Video      USD  26/02/13  4500000  12/01/13 00:20
# 3           Music         Music      USD  16/04/12   500000  17/03/12 03:24
# 4    Film & Video  Film & Video      USD  29/08/15  1950000  04/07/15 08:35
#
# ...

# %%
df = df.drop(columns=['Unnamed: 0', 'name', 'category', 'goal', 'pledged', 'usd pledged'])

# %%
df.head()
# Out:
#            ID main_category currency  deadline        launched     state  \
# 0  1000002330    Publishing      GBP  09/10/15  11/08/15 12:12    failed
# 1  1000003930  Film & Video      USD  01/11/17  02/09/17 04:43    failed
# 2  1000004038  Film & Video      USD  26/02/13  12/01/13 00:20    failed
# 3  1000007540         Music      USD  16/04/12  17/03/12 03:24    failed
# 4  1000011046  Film & Video      USD  29/08/15  04/07/15 08:35  canceled
#
#    backers country  usd_pledged_real usd_goal_real
# 0        0      GB                 0    USD 153395
# 1       15      US            242100   USD 3000000
# 2        3      US             22000   USD 4500000
# 3        1      US               100    USD 500000
# 4       14      US            128300   USD 1950000

# %%
df.dtypes
# Out:
# ID                   int64
# main_category       object
# currency            object
# deadline            object
# launched            object
# state               object
# backers              int64
# country             object
# usd_pledged_real     int64
# usd_goal_real       object
# dtype: object

# %%
# Lambda não tem uma função específica que vou fazer
# Strip remove algo no começo ou no final
df['usd_goal_real'] = df['usd_goal_real'].apply(lambda x: x.strip('USD '))

# %%
df.head()
# Out:
#            ID main_category currency  deadline        launched     state  \
# 0  1000002330    Publishing      GBP  09/10/15  11/08/15 12:12    failed
# 1  1000003930  Film & Video      USD  01/11/17  02/09/17 04:43    failed
# 2  1000004038  Film & Video      USD  26/02/13  12/01/13 00:20    failed
# 3  1000007540         Music      USD  16/04/12  17/03/12 03:24    failed
# 4  1000011046  Film & Video      USD  29/08/15  04/07/15 08:35  canceled
#
#    backers country  usd_pledged_real usd_goal_real
# 0        0      GB                 0        153395
# 1       15      US            242100       3000000
# 2        3      US             22000       4500000
# 3        1      US               100        500000
# 4       14      US            128300       1950000

# %%
# Replace muda para um novo
df['launched'] = df['launched'].str.replace(' \d\d:\d\d', '', regex=True)

# %%
df.head()
# Out:
#            ID main_category currency  deadline  launched     state  backers  \
# 0  1000002330    Publishing      GBP  09/10/15  11/08/15    failed        0
# 1  1000003930  Film & Video      USD  01/11/17  02/09/17    failed       15
# 2  1000004038  Film & Video      USD  26/02/13  12/01/13    failed        3
# 3  1000007540         Music      USD  16/04/12  17/03/12    failed        1
# 4  1000011046  Film & Video      USD  29/08/15  04/07/15  canceled       14
#
#   country  usd_pledged_real usd_goal_real
# 0      GB                 0        153395
# 1      US            242100       3000000
# 2      US             22000       4500000
# 3      US               100        500000
# 4      US            128300       1950000

# %%
df.dtypes
# Out:
# ID                   int64
# main_category       object
# currency            object
# deadline            object
# launched            object
# state               object
# backers              int64
# country             object
# usd_pledged_real     int64
# usd_goal_real       object
# dtype: object

# %%
df['usd_goal_real'] = df['usd_goal_real'].astype('int64')

# %%
df.dtypes
# Out:
# ID                   int64
# main_category       object
# currency            object
# deadline            object
# launched            object
# state               object
# backers              int64
# country             object
# usd_pledged_real     int64
# usd_goal_real        int64
# dtype: object

# %%
df['deadline'] = pd.to_datetime(df['deadline'], format='%d/%m/%y')
df['launched'] = pd.to_datetime(df['launched'], format='%d/%m/%y')

# %%
df.dtypes
# Out:
# ID                           int64
# main_category               object
# currency                    object
# deadline            datetime64[ns]
# launched            datetime64[ns]
# state                       object
# backers                      int64
# country                     object
# usd_pledged_real             int64
# usd_goal_real                int64
# dtype: object

# %%
df['time_range'] = (df['deadline']-df['launched']).dt.days

# %%
df.head()
# Out:
#            ID main_category currency   deadline   launched     state  backers  \
# 0  1000002330    Publishing      GBP 2015-10-09 2015-08-11    failed        0
# 1  1000003930  Film & Video      USD 2017-11-01 2017-09-02    failed       15
# 2  1000004038  Film & Video      USD 2013-02-26 2013-01-12    failed        3
# 3  1000007540         Music      USD 2012-04-16 2012-03-17    failed        1
# 4  1000011046  Film & Video      USD 2015-08-29 2015-07-04  canceled       14
#
#   country  usd_pledged_real  usd_goal_real  time_range
# 0      GB                 0         153395          59
# 1      US            242100        3000000          60
# 2      US             22000        4500000          45
# 3      US               100         500000          30
# 4      US            128300        1950000          56

# %%
df.dtypes
# Out:
# ID                           int64
# main_category               object
# currency                    object
# deadline            datetime64[ns]
# launched            datetime64[ns]
# state                       object
# backers                      int64
# country                     object
# usd_pledged_real             int64
# usd_goal_real                int64
# time_range                   int64
# dtype: object

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-5fcbaeda-9804-43f5-9837-51a1b811b2ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5fcbaeda-9804-43f5-9837-51a1b811b2ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### 315 Data Preparation na prática pt 02
#
# ###### Drop - eliminar colunas
# ###### Merge - parâmetros que eu quero colar no dataframe principal
# ###### how - Similar ao SQL, ('left', 'right', 'outer', 'cross')
# ###### on - qual é coluna ou parâmetro para ser colocado no outro
# ###### get_dumies Converter variáveis ​​categóricas em variáveis ​​fictícias/indicadoras
# ###### how alt code
# <h1>Tema central:</h1><p>Preparação de dados (Data Preparation)</p><h2>Tópicos abordados:</h2><h3>Importação de novos datasets</h3><ul><li>Dataset de campanha: texto, imagem, vídeo, infográfico, reviews, risco</li><li>Dataset de investimentos acima de $1000</li></ul><h3>Seleção de dados</h3><ul><li>Remoção da coluna &quot;text description&quot; por não agregar valor</li></ul><h3>Integração de dados</h3><ul><li>Merge do dataset de campanha no dataset principal pelo ID</li><li>Agregação do dataset de investimentos:<ul><li>Aplicação de one-hot encoding na coluna &quot;location&quot;</li><li>Cálculo da média das idades</li><li>Soma do número de investidores por localização</li><li>Merge no dataset principal pelo ID</li></ul></li></ul><h3>Próximos passos</h3><ul><li>Iniciar modelagem com o dataset preparado</li><li>Possivelmente mais limpeza e formatação de dados será necessária</li></ul><p>O vídeo mostra o processo de preparação dos dados, passando pelas etapas de seleção, limpeza, formatação e integração, resultando em um dataset pronto para iniciar a modelagem. Porém, provavelmente mais refinamentos serão necessários conforme o trabalho com os modelos avançar.</p>

# %%
df_c = pd.read_csv('campaign revisao.csv')

# %%
df_c.head()
# Out:
#            ID  Text Description  Video  Image  Infographic  Reviews  Risks
# 0  1000002330                 1      1      1            1        0      1
# 1  1000003930                 1      1      1            1        1      0
# 2  1000004038                 1      0      1            1        0      1
# 3  1000007540                 1      1      0            1        0      0
# 4  1000011046                 1      0      1            0        0      0

# %%
df_c['Text Description'].unique()
# Out:
# array([1])

# %%
# Retirando coluna
df_c = df_c.drop(columns=['Text Description'])

# %%
df_c.head()
# Out:
#            ID  Video  Image  Infographic  Reviews  Risks
# 0  1000002330      1      1            1        0      1
# 1  1000003930      1      1            1        1      0
# 2  1000004038      0      1            1        0      1
# 3  1000007540      1      0            1        0      0
# 4  1000011046      0      1            0        0      0

# %%
df.head()
# Out:
#            ID main_category currency   deadline   launched     state  backers  \
# 0  1000002330    Publishing      GBP 2015-10-09 2015-08-11    failed        0
# 1  1000003930  Film & Video      USD 2017-11-01 2017-09-02    failed       15
# 2  1000004038  Film & Video      USD 2013-02-26 2013-01-12    failed        3
# 3  1000007540         Music      USD 2012-04-16 2012-03-17    failed        1
# 4  1000011046  Film & Video      USD 2015-08-29 2015-07-04  canceled       14
#
#   country  usd_pledged_real  usd_goal_real  time_range
# 0      GB                 0         153395          59
# 1      US            242100        3000000          60
# 2      US             22000        4500000          45
# 3      US               100         500000          30
# 4      US            128300        1950000          56

# %%
df = df.merge(df_c, how='right', on=['ID'] )

# %%
df.head()
# Out:
#            ID main_category currency   deadline   launched     state  backers  \
# 0  1000002330    Publishing      GBP 2015-10-09 2015-08-11    failed        0
# 1  1000003930  Film & Video      USD 2017-11-01 2017-09-02    failed       15
# 2  1000004038  Film & Video      USD 2013-02-26 2013-01-12    failed        3
# 3  1000007540         Music      USD 2012-04-16 2012-03-17    failed        1
# 4  1000011046  Film & Video      USD 2015-08-29 2015-07-04  canceled       14
#
#   country  usd_pledged_real  usd_goal_real  time_range  Video  Image  \
# 0      GB                 0         153395          59      1      1
# 1      US            242100        3000000          60      1      1
# 2      US             22000        4500000          45      0      1
# 3      US               100         500000          30      1      0
# 4      US            128300        1950000          56      0      1
#
#    Infographic  Reviews  Risks
# 0            1        0      1
# ...

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-c6e3285f-b626-4eda-a617-6cb7702b9fc3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c6e3285f-b626-4eda-a617-6cb7702b9fc3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_invest = pd.read_csv('invested.csv')

# %%
df_invest.head()
# Out:
#            ID backedLocation  age
# 0  1000003930             BR   18
# 1  1000004038             US   57
# 2  1000007540             US   43
# 3  1000011046             BR   29
# 4  1000014025             BR   77

# %%
df_invest.sort_values(by= ['ID'])
# Out:
#                ID backedLocation  age
# 27400      106144             US   63
# 10585      106144            GBK   70
# 17409     1003381             BR   68
# 594       1003381             US   29
# 2925      1017454             US   62
# ...           ...            ...  ...
# 16812  1098729640            GBK   61
# 33627  1098729640            GBK   43
# 16814  1098735707             BR   66
# 33629  1098735707             US   62
# 35395  1098735707             US   63
#
# [35396 rows x 3 columns]

# %%
# Transformar em Booleana
df_invest = pd.get_dummies(df_invest, columns = ['backedLocation'])

# %%
df_invest.head()
# Out:
#            ID  age  backedLocation_BR  backedLocation_GBK  backedLocation_US
# 0  1000003930   18               True               False              False
# 1  1000004038   57              False               False               True
# 2  1000007540   43              False               False               True
# 3  1000011046   29               True               False              False
# 4  1000014025   77               True               False              False

# %%
df_invest.sort_values(by=['ID'])
# Out:
#                ID  age  backedLocation_BR  backedLocation_GBK  \
# 27400      106144   63              False               False
# 10585      106144   70              False                True
# 17409     1003381   68               True               False
# 594       1003381   29              False               False
# 2925      1017454   62              False               False
# ...           ...  ...                ...                 ...
# 16812  1098729640   61              False                True
# 33627  1098729640   43              False                True
# 16814  1098735707   66               True               False
# 33629  1098735707   62              False               False
# 35395  1098735707   63              False               False
#
#        backedLocation_US
# 27400               True
# 10585              False
# 17409              False
# 594                 True
# 2925                True
# ...                  ...
# 16812              False
# ...

# %%
df_invest = df_invest.groupby(by=['ID']).agg({'age':'mean', 'backedLocation_BR':'sum','backedLocation_GBK':'sum','backedLocation_US':'sum'})

# %%
df_invest.head()
# Out:
#           age  backedLocation_BR  backedLocation_GBK  backedLocation_US
# ID
# 106144   66.5                  0                   1                  1
# 1003381  48.5                  1                   0                  1
# 1017454  41.5                  0                   0                  2
# 1024013  77.0                  2                   0                  0
# 1024208  71.0                  0                   1                  1

# %%
# Efetuando Join
df = df.merge(df_invest, how='right', on ='ID')

# %%
df.head()
# Out:
#         ID main_category currency   deadline   launched       state  backers  \
# 0   106144         Music      USD 2014-06-15 2014-05-16      failed        1
# 1  1003381         Music      USD 2012-07-19 2012-06-21      failed       30
# 2  1017454  Film & Video      USD 2015-04-26 2015-04-20  successful        9
# 3  1024013    Publishing      USD 2012-05-18 2012-04-03      failed      136
# 4  1024208    Technology      USD 2014-09-11 2014-08-12      failed        5
#
#   country  usd_pledged_real  usd_goal_real  time_range  Video  Image  \
# 0      US              1500         180000          30      1      1
# 1      US            115900        1000000          28      0      1
# 2      US             16700            100           6      1      0
# 3      US            975805        4000000          45      1      1
# 4      US             15000         150000          30      0      1
#
#    Infographic  Reviews  Risks   age  backedLocation_BR  backedLocation_GBK  \
# ...

# %%
df.head()
